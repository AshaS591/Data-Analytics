# %% [markdown]
# <a href="https://colab.research.google.com/github/AshaS591/Data-Analytics/blob/main/practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('https://raw.githubusercontent.com/rajeevratan84/datascienceforbusiness/master/titanic.csv')
df
# Out:
#       pclass                                             name     sex  \
# 0          1                    Allen, Miss. Elisabeth Walton  female
# 1          1                   Allison, Master. Hudson Trevor    male
# 2          1                     Allison, Miss. Helen Loraine  female
# 3          1             Allison, Mr. Hudson Joshua Creighton    male
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...      ...                                              ...     ...
# 1304       3                             Zabour, Miss. Hileni  female
# 1305       3                            Zabour, Miss. Thamine  female
# 1306       3                        Zakarian, Mr. Mapriededer    male
# 1307       3                              Zakarian, Mr. Ortin    male
# 1308       3                               Zimmerman, Mr. Leo    male
#
#           age  sibsp  parch  ticket      fare    cabin embarked  survived
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    1309 non-null   int64
#  1   name      1309 non-null   object
#  2   sex       1309 non-null   object
#  3   age       1046 non-null   float64
#  4   sibsp     1309 non-null   int64
#  5   parch     1309 non-null   int64
#  6   ticket    1309 non-null   object
#  7   fare      1308 non-null   float64
#  8   cabin     295 non-null    object
#  9   embarked  1307 non-null   object
#  10  survived  1309 non-null   int64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 112.6+ KB

# %%
df.columns
# Out:
# Index(['pclass', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket', 'fare',
#        'cabin', 'embarked', 'survived'],
#       dtype='object')

# %%
d={'fare':'Fare'}
df.rename(columns=d,inplace=True)

# %%
df.head()
# Out:
#    pclass                                             name     sex      age  \
# 0       1                    Allen, Miss. Elisabeth Walton  female  29.0000
# 1       1                   Allison, Master. Hudson Trevor    male   0.9167
# 2       1                     Allison, Miss. Helen Loraine  female   2.0000
# 3       1             Allison, Mr. Hudson Joshua Creighton    male  30.0000
# 4       1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000
#
#    sibsp  parch  ticket      Fare    cabin embarked  survived
# 0      0      0   24160  211.3375       B5        S         1
# 1      1      2  113781  151.5500  C22 C26        S         1
# 2      1      2  113781  151.5500  C22 C26        S         0
# 3      1      2  113781  151.5500  C22 C26        S         0
# 4      1      2  113781  151.5500  C22 C26        S         0

# %%
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    1309 non-null   int64
#  1   name      1309 non-null   object
#  2   sex       1309 non-null   object
#  3   age       1046 non-null   float64
#  4   sibsp     1309 non-null   int64
#  5   parch     1309 non-null   int64
#  6   ticket    1309 non-null   object
#  7   Fare      1308 non-null   float64
#  8   cabin     295 non-null    object
#  9   embarked  1307 non-null   object
#  10  survived  1309 non-null   int64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 112.6+ KB

# %%
df['pclass'].unique()
# Out:
# array([1, 2, 3])

# %%
d={1:'One',2:'Two',3:'Three'}
df['pclass']=df['pclass'].map(d)

# %%
df
# Out:
#      pclass                                             name     sex      age  \
# 0       One                    Allen, Miss. Elisabeth Walton  female  29.0000
# 1       One                   Allison, Master. Hudson Trevor    male   0.9167
# 2       One                     Allison, Miss. Helen Loraine  female   2.0000
# 3       One             Allison, Mr. Hudson Joshua Creighton    male  30.0000
# 4       One  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000
# ...     ...                                              ...     ...      ...
# 1304  Three                             Zabour, Miss. Hileni  female  14.5000
# 1305  Three                            Zabour, Miss. Thamine  female      NaN
# 1306  Three                        Zakarian, Mr. Mapriededer    male  26.5000
# 1307  Three                              Zakarian, Mr. Ortin    male  27.0000
# 1308  Three                               Zimmerman, Mr. Leo    male  29.0000
#
# ...

# %%
df=pd.read_csv('https://raw.githubusercontent.com/rajeevratan84/datascienceforbusiness/master/amazon_fires.csv',encoding='ISO-8859-1')
df
# Out:
#        ano       mes     estado   numero  encontro
# 0     1998   Janeiro       Acre  0 Fires  1/1/1998
# 1     1999   Janeiro       Acre  0 Fires  1/1/1999
# 2     2000   Janeiro       Acre  0 Fires  1/1/2000
# 3     2001   Janeiro       Acre  0 Fires  1/1/2001
# 4     2002   Janeiro       Acre  0 Fires  1/1/2002
# ...    ...       ...        ...      ...       ...
# 6449  2012  Dezembro  Tocantins      128  1/1/2012
# 6450  2013  Dezembro  Tocantins       85  1/1/2013
# 6451  2014  Dezembro  Tocantins      223  1/1/2014
# 6452  2015  Dezembro  Tocantins      373  1/1/2015
# 6453  2016  Dezembro  Tocantins      119  1/1/2016
#
# [6454 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['ano', 'mes', 'estado', 'numero', 'encontro'], dtype='object')

# %%
df['numero']=df['numero'].str.strip(' Fires')

# %%
df
# Out:
#        ano       mes     estado numero  encontro
# 0     1998   Janeiro       Acre      0  1/1/1998
# 1     1999   Janeiro       Acre      0  1/1/1999
# 2     2000   Janeiro       Acre      0  1/1/2000
# 3     2001   Janeiro       Acre      0  1/1/2001
# 4     2002   Janeiro       Acre      0  1/1/2002
# ...    ...       ...        ...    ...       ...
# 6449  2012  Dezembro  Tocantins    128  1/1/2012
# 6450  2013  Dezembro  Tocantins     85  1/1/2013
# 6451  2014  Dezembro  Tocantins    223  1/1/2014
# 6452  2015  Dezembro  Tocantins    373  1/1/2015
# 6453  2016  Dezembro  Tocantins    119  1/1/2016
#
# [6454 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6454 entries, 0 to 6453
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ano       6454 non-null   int64
#  1   mes       6454 non-null   object
#  2   estado    6454 non-null   object
#  3   numero    6322 non-null   object
#  4   encontro  6454 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 252.2+ KB

# %%
df['mes']=df['mes'].str.lower()
df
# Out:
#        ano       mes     estado numero  encontro
# 0     1998   janeiro       Acre      0  1/1/1998
# 1     1999   janeiro       Acre      0  1/1/1999
# 2     2000   janeiro       Acre      0  1/1/2000
# 3     2001   janeiro       Acre      0  1/1/2001
# 4     2002   janeiro       Acre      0  1/1/2002
# ...    ...       ...        ...    ...       ...
# 6449  2012  dezembro  Tocantins    128  1/1/2012
# 6450  2013  dezembro  Tocantins     85  1/1/2013
# 6451  2014  dezembro  Tocantins    223  1/1/2014
# 6452  2015  dezembro  Tocantins    373  1/1/2015
# 6453  2016  dezembro  Tocantins    119  1/1/2016
#
# [6454 rows x 5 columns]

# %%
df['numero']=df['numero'].astype(float)
# df['numero']=df['numero'].astype(int)

# %%
df['numero'].mean()
# Out:
# 110.66797152799748

# %%
# df.dropna(inplace=True)

# %%
df
# Out:
#        ano       mes     estado  numero  encontro
# 0     1998   janeiro       Acre     0.0  1/1/1998
# 1     1999   janeiro       Acre     0.0  1/1/1999
# 2     2000   janeiro       Acre     0.0  1/1/2000
# 3     2001   janeiro       Acre     0.0  1/1/2001
# 4     2002   janeiro       Acre     0.0  1/1/2002
# ...    ...       ...        ...     ...       ...
# 6449  2012  dezembro  Tocantins   128.0  1/1/2012
# 6450  2013  dezembro  Tocantins    85.0  1/1/2013
# 6451  2014  dezembro  Tocantins   223.0  1/1/2014
# 6452  2015  dezembro  Tocantins   373.0  1/1/2015
# 6453  2016  dezembro  Tocantins   119.0  1/1/2016
#
# [6454 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6454 entries, 0 to 6453
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ano       6454 non-null   int64
#  1   mes       6454 non-null   object
#  2   estado    6454 non-null   object
#  3   numero    6322 non-null   float64
#  4   encontro  6454 non-null   object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 252.2+ KB

# %%
avg=df['numero'].mean()
df['numero']=df['numero'].fillna(avg)
df
# Out:
#        ano       mes     estado  numero  encontro
# 0     1998   janeiro       Acre     0.0  1/1/1998
# 1     1999   janeiro       Acre     0.0  1/1/1999
# 2     2000   janeiro       Acre     0.0  1/1/2000
# 3     2001   janeiro       Acre     0.0  1/1/2001
# 4     2002   janeiro       Acre     0.0  1/1/2002
# ...    ...       ...        ...     ...       ...
# 6449  2012  dezembro  Tocantins   128.0  1/1/2012
# 6450  2013  dezembro  Tocantins    85.0  1/1/2013
# 6451  2014  dezembro  Tocantins   223.0  1/1/2014
# 6452  2015  dezembro  Tocantins   373.0  1/1/2015
# 6453  2016  dezembro  Tocantins   119.0  1/1/2016
#
# [6454 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6454 entries, 0 to 6453
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ano       6454 non-null   int64
#  1   mes       6454 non-null   object
#  2   estado    6454 non-null   object
#  3   numero    6454 non-null   float64
#  4   encontro  6454 non-null   object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 252.2+ KB

# %%
df.tail(20)
# Out:
#        ano       mes     estado  numero  encontro
# 6434  2017  novembro  Tocantins   434.0  1/1/2017
# 6435  1998  dezembro  Tocantins     9.0  1/1/1998
# 6436  1999  dezembro  Tocantins    16.0  1/1/1999
# 6437  2000  dezembro  Tocantins    20.0  1/1/2000
# 6438  2001  dezembro  Tocantins    21.0  1/1/2001
# 6439  2002  dezembro  Tocantins    39.0  1/1/2002
# 6440  2003  dezembro  Tocantins   109.0  1/1/2003
# 6441  2004  dezembro  Tocantins    96.0  1/1/2004
# 6442  2005  dezembro  Tocantins    53.0  1/1/2005
# 6443  2006  dezembro  Tocantins    15.0  1/1/2006
# 6444  2007  dezembro  Tocantins    13.0  1/1/2007
# 6445  2008  dezembro  Tocantins     7.0  1/1/2008
# 6446  2009  dezembro  Tocantins    46.0  1/1/2009
# 6447  2010  dezembro  Tocantins    72.0  1/1/2010
# 6448  2011  dezembro  Tocantins   105.0  1/1/2011
# 6449  2012  dezembro  Tocantins   128.0  1/1/2012
# 6450  2013  dezembro  Tocantins    85.0  1/1/2013
# 6451  2014  dezembro  Tocantins   223.0  1/1/2014
# ...

# %%
avg
# Out:
# 110.66797152799748

# %%
df['numero']=df['numero'].astype(int)
df
# Out:
#        ano       mes     estado  numero  encontro
# 0     1998   janeiro       Acre       0  1/1/1998
# 1     1999   janeiro       Acre       0  1/1/1999
# 2     2000   janeiro       Acre       0  1/1/2000
# 3     2001   janeiro       Acre       0  1/1/2001
# 4     2002   janeiro       Acre       0  1/1/2002
# ...    ...       ...        ...     ...       ...
# 6449  2012  dezembro  Tocantins     128  1/1/2012
# 6450  2013  dezembro  Tocantins      85  1/1/2013
# 6451  2014  dezembro  Tocantins     223  1/1/2014
# 6452  2015  dezembro  Tocantins     373  1/1/2015
# 6453  2016  dezembro  Tocantins     119  1/1/2016
#
# [6454 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['ano', 'mes', 'estado', 'numero', 'encontro'], dtype='object')

# %%
new=[4,0,2,1]
df=df[df.columns[new]]

# %%
df
# Out:
#       encontro   ano     estado       mes
# 0     1/1/1998  1998       Acre   janeiro
# 1     1/1/1999  1999       Acre   janeiro
# 2     1/1/2000  2000       Acre   janeiro
# 3     1/1/2001  2001       Acre   janeiro
# 4     1/1/2002  2002       Acre   janeiro
# ...        ...   ...        ...       ...
# 6449  1/1/2012  2012  Tocantins  dezembro
# 6450  1/1/2013  2013  Tocantins  dezembro
# 6451  1/1/2014  2014  Tocantins  dezembro
# 6452  1/1/2015  2015  Tocantins  dezembro
# 6453  1/1/2016  2016  Tocantins  dezembro
#
# [6454 rows x 4 columns]

# %%
df['mes']=df['mes'].str.replace('dezembro','Dece')
df
# Out:
# <ipython-input-312-17ea1c3df912>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['mes']=df['mes'].str.replace('dezembro','Dece')
#       encontro   ano     estado      mes
# 0     1/1/1998  1998       Acre  janeiro
# 1     1/1/1999  1999       Acre  janeiro
# 2     1/1/2000  2000       Acre  janeiro
# 3     1/1/2001  2001       Acre  janeiro
# 4     1/1/2002  2002       Acre  janeiro
# ...        ...   ...        ...      ...
# 6449  1/1/2012  2012  Tocantins     Dece
# 6450  1/1/2013  2013  Tocantins     Dece
# 6451  1/1/2014  2014  Tocantins     Dece
# 6452  1/1/2015  2015  Tocantins     Dece
# 6453  1/1/2016  2016  Tocantins     Dece
#
# [6454 rows x 4 columns]

# %%
df.drop(['encontro','ano'],axis=1,inplace=True)
# Out:
# <ipython-input-313-6f70f5f680e3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['encontro','ano'],axis=1,inplace=True)

# %%
df
# Out:
#          estado      mes
# 0          Acre  janeiro
# 1          Acre  janeiro
# 2          Acre  janeiro
# 3          Acre  janeiro
# 4          Acre  janeiro
# ...         ...      ...
# 6449  Tocantins     Dece
# 6450  Tocantins     Dece
# 6451  Tocantins     Dece
# 6452  Tocantins     Dece
# 6453  Tocantins     Dece
#
# [6454 rows x 2 columns]

# %%
df.drop(df.index[0],inplace=True)
# Out:
# <ipython-input-315-0a4f20073af0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(df.index[0],inplace=True)

# %%
df
# Out:
#          estado      mes
# 1          Acre  janeiro
# 2          Acre  janeiro
# 3          Acre  janeiro
# 4          Acre  janeiro
# 5          Acre  janeiro
# ...         ...      ...
# 6449  Tocantins     Dece
# 6450  Tocantins     Dece
# 6451  Tocantins     Dece
# 6452  Tocantins     Dece
# 6453  Tocantins     Dece
#
# [6453 rows x 2 columns]

# %%
df.reset_index(inplace=True)
df
# Out:
#       index     estado      mes
# 0         1       Acre  janeiro
# 1         2       Acre  janeiro
# 2         3       Acre  janeiro
# 3         4       Acre  janeiro
# 4         5       Acre  janeiro
# ...     ...        ...      ...
# 6448   6449  Tocantins     Dece
# 6449   6450  Tocantins     Dece
# 6450   6451  Tocantins     Dece
# 6451   6452  Tocantins     Dece
# 6452   6453  Tocantins     Dece
#
# [6453 rows x 3 columns]

# %%
df.set_index('mes',inplace=True)
df
# Out:
#          index     estado
# mes
# janeiro      1       Acre
# janeiro      2       Acre
# janeiro      3       Acre
# janeiro      4       Acre
# janeiro      5       Acre
# ...        ...        ...
# Dece      6449  Tocantins
# Dece      6450  Tocantins
# Dece      6451  Tocantins
# Dece      6452  Tocantins
# Dece      6453  Tocantins
#
# [6453 rows x 2 columns]
