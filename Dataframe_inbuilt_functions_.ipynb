# %% [markdown]
# <a href="https://colab.research.google.com/github/AshaS591/Data-Analytics/blob/main/Dataframe_inbuilt_functions_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Gui

# %%
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/rajeevratan84/datascienceforbusiness/master/titanic.csv")

# %%
df
# Out:
#       pclass                                             name     sex  \
# 0          1                    Allen, Miss. Elisabeth Walton  female
# 1          1                   Allison, Master. Hudson Trevor    male
# 2          1                     Allison, Miss. Helen Loraine  female
# 3          1             Allison, Mr. Hudson Joshua Creighton    male
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...      ...                                              ...     ...
# 1304       3                             Zabour, Miss. Hileni  female
# 1305       3                            Zabour, Miss. Thamine  female
# 1306       3                        Zakarian, Mr. Mapriededer    male
# 1307       3                              Zakarian, Mr. Ortin    male
# 1308       3                               Zimmerman, Mr. Leo    male
#
#           age  sibsp  parch  ticket      fare    cabin embarked  survived
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    1309 non-null   int64
#  1   name      1309 non-null   object
#  2   sex       1309 non-null   object
#  3   age       1046 non-null   float64
#  4   sibsp     1309 non-null   int64
#  5   parch     1309 non-null   int64
#  6   ticket    1309 non-null   object
#  7   fare      1308 non-null   float64
#  8   cabin     295 non-null    object
#  9   embarked  1307 non-null   object
#  10  survived  1309 non-null   int64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 112.6+ KB

# %%
df.tail()
# Out:
#       pclass                       name     sex   age  sibsp  parch  ticket  \
# 1304       3       Zabour, Miss. Hileni  female  14.5      1      0    2665
# 1305       3      Zabour, Miss. Thamine  female   NaN      1      0    2665
# 1306       3  Zakarian, Mr. Mapriededer    male  26.5      0      0    2656
# 1307       3        Zakarian, Mr. Ortin    male  27.0      0      0    2670
# 1308       3         Zimmerman, Mr. Leo    male  29.0      0      0  315082
#
#          fare cabin embarked  survived
# 1304  14.4542   NaN        C         0
# 1305  14.4542   NaN        C         0
# 1306   7.2250   NaN        C         0
# 1307   7.2250   NaN        C         0
# 1308   7.8750   NaN        S         0

# %%
df.head()
# Out:
#    pclass                                             name     sex      age  \
# 0       1                    Allen, Miss. Elisabeth Walton  female  29.0000
# 1       1                   Allison, Master. Hudson Trevor    male   0.9167
# 2       1                     Allison, Miss. Helen Loraine  female   2.0000
# 3       1             Allison, Mr. Hudson Joshua Creighton    male  30.0000
# 4       1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000
#
#    sibsp  parch  ticket      fare    cabin embarked  survived
# 0      0      0   24160  211.3375       B5        S         1
# 1      1      2  113781  151.5500  C22 C26        S         1
# 2      1      2  113781  151.5500  C22 C26        S         0
# 3      1      2  113781  151.5500  C22 C26        S         0
# 4      1      2  113781  151.5500  C22 C26        S         0

# %%
df.describe()
# Out:
#             pclass          age        sibsp        parch         fare  \
# count  1309.000000  1046.000000  1309.000000  1309.000000  1308.000000
# mean      2.294882    29.881135     0.498854     0.385027    33.295479
# std       0.837836    14.413500     1.041658     0.865560    51.758668
# min       1.000000     0.166700     0.000000     0.000000     0.000000
# 25%       2.000000    21.000000     0.000000     0.000000     7.895800
# 50%       3.000000    28.000000     0.000000     0.000000    14.454200
# 75%       3.000000    39.000000     1.000000     0.000000    31.275000
# max       3.000000    80.000000     8.000000     9.000000   512.329200
#
#           survived
# count  1309.000000
# mean      0.381971
# std       0.486055
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
df.describe (include = object )
# Out:
#                         name   sex    ticket        cabin embarked
# count                   1309  1309      1309          295     1307
# unique                  1307     2       929          186        3
# top     Connolly, Miss. Kate  male  CA. 2343  C23 C25 C27        S
# freq                       2   843        11            6      914

# %%
df.shape
# Out:
# (1309, 11)

# %%
df.columns
# Out:
# Index(['pclass', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket', 'fare',
#        'cabin', 'embarked', 'survived'],
#       dtype='object')

# %%
df['sex'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %% [markdown]
# df['Ticket '].unique ()

# %%
df['ticket'].unique ()
# Out:
# array(['24160', '113781', '19952', '13502', '112050', '11769', 'PC 17609',
#        'PC 17757', 'PC 17477', '19877', '27042', 'PC 17318', 'PC 17558',
#        '11813', '13050', '11751', '111369', 'PC 17483', '13905', '11967',
#        'PC 17760', '110564', '113784', '112277', '36928', '113783',
#        '110489', 'PC 17608', '113505', '111427', '113054', 'PC 17591',
#        '112379', 'PC 17610', '16966', '113050', '113798', 'PC 17476',
#        'PC 17606', 'PC 17755', '695', '113059', '113760', '19924',
#        '17770', 'W.E.P. 5734', '113806', '110152', 'PC 17594', '112051',
#        '13508', '110465', '5727', 'PC 17756', '11770', '113791',
#        'WE/P 5735', '112901', 'PC 17599', '113055', '113804',
#        'F.C. 12750', '17474', '33638', 'PC 17761', '11755', 'PC 17485',
#        'PC 17580', '11767', '36947', 'PC 17531', 'PC 17598', '17421',
#        'PC 17474', '113051', '19950', '113778', 'PC 17611', '17765',
# ...

# %%
df['sex'].value_counts()
# Out:
# sex
# male      843
# female    466
# Name: count, dtype: int64

# %%
df['ticket'].value_counts()
# Out:
# ticket
# CA. 2343    11
# 1601         8
# CA 2144      8
# PC 17608     7
# 347077       7
#             ..
# 373450       1
# 2223         1
# 350046       1
# 3101281      1
# 315082       1
# Name: count, Length: 929, dtype: int64

# %%
df['cabin'].value_counts()
# Out:
# cabin
# C23 C25 C27        6
# G6                 5
# B57 B59 B63 B66    5
# F4                 4
# F33                4
#                   ..
# C132               1
# E60                1
# B52 B54 B56        1
# C49                1
# F38                1
# Name: count, Length: 186, dtype: int64

# %%
text=df.to_csv('/content/titanic.txt')

# %%
df.columns
# Out:
# Index(['pclass', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket', 'fare',
#        'cabin', 'embarked', 'survived'],
#       dtype='object')

# %%
df.loc[::5,'cabin']
# Out:
# 0            B5
# 5           E12
# 10      C62 C64
# 15          NaN
# 20          D35
#          ...
# 1285        NaN
# 1290        NaN
# 1295        NaN
# 1300        NaN
# 1305        NaN
# Name: cabin, Length: 262, dtype: object

# %%
df.loc[1:10,['name',"cabin","age"]]
# Out:
#                                                name    cabin      age
# 1                    Allison, Master. Hudson Trevor  C22 C26   0.9167
# 2                      Allison, Miss. Helen Loraine  C22 C26   2.0000
# 3              Allison, Mr. Hudson Joshua Creighton  C22 C26  30.0000
# 4   Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  C22 C26  25.0000
# 5                               Anderson, Mr. Harry      E12  48.0000
# 6                 Andrews, Miss. Kornelia Theodosia       D7  63.0000
# 7                            Andrews, Mr. Thomas Jr      A36  39.0000
# 8     Appleton, Mrs. Edward Dale (Charlotte Lamson)     C101  53.0000
# 9                           Artagaveytia, Mr. Ramon      NaN  71.0000
# 10                           Astor, Col. John Jacob  C62 C64  47.0000

# %%
df.loc[[1,20,30,50],['name','fare','cabin','sibsp']]
# Out:
#                                                  name      fare        cabin  \
# 1                      Allison, Master. Hudson Trevor  151.5500      C22 C26
# 20                      Beckwith, Mr. Richard Leonard   52.5542          D35
# 30                       Blackwell, Mr. Stephen Weart   35.5000            T
# 50  Cardeza, Mrs. James Warburton Martinez (Charlo...  512.3292  B51 B53 B55
#
#     sibsp
# 1       1
# 20      1
# 30      0
# 50      0

# %%
df.loc[[10,200,300,500],['name','fare','sex','sibsp']]
# Out:
#                              name      fare   sex  sibsp
# 10         Astor, Col. John Jacob  227.5250  male      1
# 200  McCaffry, Mr. Thomas Francis   75.2417  male      0
# 300     Van der hoef, Mr. Wyckoff   33.5000  male      0
# 500       McKane, Mr. Peter David   26.0000  male      0

# %%
df.iloc[1:10,0:6]
# Out:
#    pclass                                             name     sex      age  \
# 1       1                   Allison, Master. Hudson Trevor    male   0.9167
# 2       1                     Allison, Miss. Helen Loraine  female   2.0000
# 3       1             Allison, Mr. Hudson Joshua Creighton    male  30.0000
# 4       1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000
# 5       1                              Anderson, Mr. Harry    male  48.0000
# 6       1                Andrews, Miss. Kornelia Theodosia  female  63.0000
# 7       1                           Andrews, Mr. Thomas Jr    male  39.0000
# 8       1    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female  53.0000
# 9       1                          Artagaveytia, Mr. Ramon    male  71.0000
#
#    sibsp  parch
# 1      1      2
# 2      1      2
# 3      1      2
# 4      1      2
# 5      0      0
# 6      1      0
# 7      0      0
# 8      2      0
# 9      0      0

# %%
df.iloc[1:10,::2]
# Out:
#    pclass     sex  sibsp    ticket    cabin  survived
# 1       1    male      1    113781  C22 C26         1
# 2       1  female      1    113781  C22 C26         0
# 3       1    male      1    113781  C22 C26         0
# 4       1  female      1    113781  C22 C26         0
# 5       1    male      0     19952      E12         1
# 6       1  female      1     13502       D7         1
# 7       1    male      0    112050      A36         0
# 8       1  female      2     11769     C101         1
# 9       1    male      0  PC 17609      NaN         0

# %%
df.iloc[1:101,::-1]
# Out:
#      survived embarked    cabin      fare    ticket  parch  sibsp      age  \
# 1           1        S  C22 C26  151.5500    113781      2      1   0.9167
# 2           0        S  C22 C26  151.5500    113781      2      1   2.0000
# 3           0        S  C22 C26  151.5500    113781      2      1  30.0000
# 4           0        S  C22 C26  151.5500    113781      2      1  25.0000
# 5           1        S      E12   26.5500     19952      0      0  48.0000
# ..        ...      ...      ...       ...       ...    ...    ...      ...
# 96          0        C      C86  106.4250  PC 17761      0      1  50.0000
# 97          1        C  B58 B60  247.5208  PC 17558      1      1  27.0000
# 98          1        C      C86  106.4250  PC 17761      0      1  48.0000
# 99          1        C      A16   39.6000     11755      0      1  48.0000
# 100         1        C      A20   56.9292  PC 17485      0      1  49.0000
#
# ...

# %%
df.iloc[::2,::-1]
# Out:
#       survived embarked    cabin      fare  ticket  parch  sibsp   age  \
# 0            1        S       B5  211.3375   24160      0      0  29.0
# 2            0        S  C22 C26  151.5500  113781      2      1   2.0
# 4            0        S  C22 C26  151.5500  113781      2      1  25.0
# 6            1        S       D7   77.9583   13502      0      1  63.0
# 8            1        S     C101   51.4792   11769      0      2  53.0
# ...        ...      ...      ...       ...     ...    ...    ...   ...
# 1300         1        C      NaN   14.4542    2659      0      1  15.0
# 1302         0        C      NaN    7.2250    2647      0      0   NaN
# 1304         0        C      NaN   14.4542    2665      0      1  14.5
# 1306         0        C      NaN    7.2250    2656      0      0  26.5
# 1308         0        S      NaN    7.8750  315082      0      0  29.0
#
#          sex                                             name  pclass
# ...

# %% [markdown]
# # To fetch data from specific columns using iloc **variable**

# %%
df.iloc[::2,[2,3,5,6]]
# Out:
#          sex   age  parch  ticket
# 0     female  29.0      0   24160
# 2     female   2.0      2  113781
# 4     female  25.0      2  113781
# 6     female  63.0      0   13502
# 8     female  53.0      0   11769
# ...      ...   ...    ...     ...
# 1300  female  15.0      0    2659
# 1302    male   NaN      0    2647
# 1304  female  14.5      0    2665
# 1306    male  26.5      0    2656
# 1308    male  29.0      0  315082
#
# [655 rows x 4 columns]

# %% [markdown]
# # To fetch data from specific rows using iloc **variable**

# %%
df.iloc[[1,4,5],[2,3,4]]
# Out:
#       sex      age  sibsp
# 1    male   0.9167      1
# 4  female  25.0000      1
# 5    male  48.0000      0

# %% [markdown]
# #1.fetch data

# %%
df.loc[1:100,['name','age','cabin','embarked']]
# Out:
#                                                   name      age    cabin  \
# 1                       Allison, Master. Hudson Trevor   0.9167  C22 C26
# 2                         Allison, Miss. Helen Loraine   2.0000  C22 C26
# 3                 Allison, Mr. Hudson Joshua Creighton  30.0000  C22 C26
# 4      Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  25.0000  C22 C26
# 5                                  Anderson, Mr. Harry  48.0000      E12
# ..                                                 ...      ...      ...
# 96                          Douglas, Mr. Walter Donald  50.0000      C86
# 97   Douglas, Mrs. Frederick Charles (Mary Helene B...  27.0000  B58 B60
# 98         Douglas, Mrs. Walter Donald (Mahala Dutton)  48.0000      C86
# 99   Duff Gordon, Lady. (Lucille Christiana Sutherl...  48.0000      A16
# 100       Duff Gordon, Sir. Cosmo Edmund ("Mr Morgan")  49.0000      A20
#
#     embarked
# 1          S
# 2          S
# 3          S
# 4          S
# 5          S
# ...

# %%
df.loc[0:891:2,['survived','sex','pclass']]
# Out:
#      survived     sex  pclass
# 0           1  female       1
# 2           0  female       1
# 4           0  female       1
# 6           1  female       1
# 8           1  female       1
# ..        ...     ...     ...
# 882         0    male       3
# 884         0    male       3
# 886         1  female       3
# 888         0    male       3
# 890         0    male       3
#
# [446 rows x 3 columns]

# %%
df.loc[1::2,['age','name','pclass','cabin']]
# Out:
#           age                                  name  pclass    cabin
# 1      0.9167        Allison, Master. Hudson Trevor       1  C22 C26
# 3     30.0000  Allison, Mr. Hudson Joshua Creighton       1  C22 C26
# 5     48.0000                   Anderson, Mr. Harry       1      E12
# 7     39.0000                Andrews, Mr. Thomas Jr       1      A36
# 9     71.0000               Artagaveytia, Mr. Ramon       1      NaN
# ...       ...                                   ...     ...      ...
# 1299  27.0000                   Yasbeck, Mr. Antoni       3      NaN
# 1301  45.5000                  Youseff, Mr. Gerious       3      NaN
# 1303      NaN                 Yousseff, Mr. Gerious       3      NaN
# 1305      NaN                 Zabour, Miss. Thamine       3      NaN
# 1307  27.0000                   Zakarian, Mr. Ortin       3      NaN
#
# [654 rows x 4 columns]

# %%
df.iloc[::-1,::-1]
# Out:
#       survived embarked    cabin      fare  ticket  parch  sibsp      age  \
# 1308         0        S      NaN    7.8750  315082      0      0  29.0000
# 1307         0        C      NaN    7.2250    2670      0      0  27.0000
# 1306         0        C      NaN    7.2250    2656      0      0  26.5000
# 1305         0        C      NaN   14.4542    2665      0      1      NaN
# 1304         0        C      NaN   14.4542    2665      0      1  14.5000
# ...        ...      ...      ...       ...     ...    ...    ...      ...
# 4            0        S  C22 C26  151.5500  113781      2      1  25.0000
# 3            0        S  C22 C26  151.5500  113781      2      1  30.0000
# 2            0        S  C22 C26  151.5500  113781      2      1   2.0000
# 1            1        S  C22 C26  151.5500  113781      2      1   0.9167
# 0            1        S       B5  211.3375   24160      0      0  29.0000
#
#          sex                                             name  pclass
# ...

# %%
df.iloc[::2,1::3]
# Out:
#                                                  name  sibsp      fare  \
# 0                       Allen, Miss. Elisabeth Walton      0  211.3375
# 2                        Allison, Miss. Helen Loraine      1  151.5500
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)      1  151.5500
# 6                   Andrews, Miss. Kornelia Theodosia      1   77.9583
# 8       Appleton, Mrs. Edward Dale (Charlotte Lamson)      2   51.4792
# ...                                               ...    ...       ...
# 1300          Yasbeck, Mrs. Antoni (Selini Alexander)      1   14.4542
# 1302                                Yousif, Mr. Wazli      0    7.2250
# 1304                             Zabour, Miss. Hileni      1   14.4542
# 1306                        Zakarian, Mr. Mapriededer      0    7.2250
# 1308                               Zimmerman, Mr. Leo      0    7.8750
#
#       survived
# 0            1
# 2            0
# 4            0
# 6            1
# 8            1
# ...        ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    1309 non-null   int64
#  1   name      1309 non-null   object
#  2   sex       1309 non-null   object
#  3   age       1046 non-null   float64
#  4   sibsp     1309 non-null   int64
#  5   parch     1309 non-null   int64
#  6   ticket    1309 non-null   object
#  7   fare      1308 non-null   float64
#  8   cabin     295 non-null    object
#  9   embarked  1307 non-null   object
#  10  survived  1309 non-null   int64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 112.6+ KB

# %%
df.info()
df.iloc[1000:1:-1,[2,3,4,5]]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    1309 non-null   int64
#  1   name      1309 non-null   object
#  2   sex       1309 non-null   object
#  3   age       1046 non-null   float64
#  4   sibsp     1309 non-null   int64
#  5   parch     1309 non-null   int64
#  6   ticket    1309 non-null   object
#  7   fare      1308 non-null   float64
#  8   cabin     295 non-null    object
#  9   embarked  1307 non-null   object
#  10  survived  1309 non-null   int64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 112.6+ KB
#          sex   age  sibsp  parch
# 1000    male   NaN      0      0
# 999   female   NaN      0      0
# 998     male   NaN      0      0
# 997   female   NaN      0      0
# 996     male  33.0      0      0
# ...      ...   ...    ...    ...
# 6     female  63.0      1      0
# ...

# %%
df[df['sex']=='female']
# Out:
#       pclass                                             name     sex   age  \
# 0          1                    Allen, Miss. Elisabeth Walton  female  29.0
# 2          1                     Allison, Miss. Helen Loraine  female   2.0
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0
# 6          1                Andrews, Miss. Kornelia Theodosia  female  63.0
# 8          1    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female  53.0
# ...      ...                                              ...     ...   ...
# 1286       3  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)  female  38.0
# 1290       3                 Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 1300       3          Yasbeck, Mrs. Antoni (Selini Alexander)  female  15.0
# 1304       3                             Zabour, Miss. Hileni  female  14.5
# 1305       3                            Zabour, Miss. Thamine  female   NaN
#
# ...

# %%
df[df['age']>25]
# Out:
#       pclass                                  name     sex   age  sibsp  \
# 0          1         Allen, Miss. Elisabeth Walton  female  29.0      0
# 3          1  Allison, Mr. Hudson Joshua Creighton    male  30.0      1
# 5          1                   Anderson, Mr. Harry    male  48.0      0
# 6          1     Andrews, Miss. Kornelia Theodosia  female  63.0      1
# 7          1                Andrews, Mr. Thomas Jr    male  39.0      0
# ...      ...                                   ...     ...   ...    ...
# 1299       3                   Yasbeck, Mr. Antoni    male  27.0      1
# 1301       3                  Youseff, Mr. Gerious    male  45.5      0
# 1306       3             Zakarian, Mr. Mapriededer    male  26.5      0
# 1307       3                   Zakarian, Mr. Ortin    male  27.0      0
# 1308       3                    Zimmerman, Mr. Leo    male  29.0      0
#
#       parch  ticket      fare    cabin embarked  survived
# ...

# %%
df[(df['age']>50) & (df['survived']==1)]
# Out:
#       pclass                                               name     sex   age  \
# 6          1                  Andrews, Miss. Kornelia Theodosia  female  63.0
# 8          1      Appleton, Mrs. Edward Dale (Charlotte Lamson)  female  53.0
# 14         1               Barkworth, Mr. Algernon Henry Wilson    male  80.0
# 33         1                           Bonnell, Miss. Elizabeth  female  58.0
# 42         1     Brown, Mrs. John Murray (Caroline Lane Lamson)  female  59.0
# 43         1    Bucknell, Mrs. William Robert (Emma Eliza Ward)  female  60.0
# 48         1   Candee, Mrs. Edward (Helen Churchill Hungerford)  female  53.0
# 50         1  Cardeza, Mrs. James Warburton Martinez (Charlo...  female  58.0
# 61         1  Cavendish, Mrs. Tyrell William (Julia Florence...  female  76.0
# 78         1  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...  female  64.0
# 79         1  Cornell, Mrs. Robert Clifford (Malvina Helen L...  female  55.0
# ...

# %%
df[(df['pclass']==1) | (df['pclass']==2) ]
# Out:
#      pclass                                             name     sex      age  \
# 0         1                    Allen, Miss. Elisabeth Walton  female  29.0000
# 1         1                   Allison, Master. Hudson Trevor    male   0.9167
# 2         1                     Allison, Miss. Helen Loraine  female   2.0000
# 3         1             Allison, Mr. Hudson Joshua Creighton    male  30.0000
# 4         1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000
# ..      ...                                              ...     ...      ...
# 595       2                   Wheeler, Mr. Edwin "Frederick"    male      NaN
# 596       2                            Wilhelms, Mr. Charles    male  31.0000
# 597       2                     Williams, Mr. Charles Eugene    male      NaN
# 598       2                             Wright, Miss. Marion  female  26.0000
# 599       2           Yrois, Miss. Henriette ("Mrs Harbeck")  female  24.0000
#
# ...

# %%
df[(df['survived']==0) & (df['age']<20) & (df['embarked']=='S')]
# Out:
#       pclass                                  name     sex   age  sibsp  \
# 2          1          Allison, Miss. Helen Loraine  female   2.0      1
# 53         1                Carrau, Mr. Jose Pedro    male  17.0      0
# 114        1        Fortune, Mr. Charles Alexander    male  19.0      3
# 197        1             Marvin, Mr. Daniel Warner    male  19.0      1
# 326        2            Andrew, Mr. Edgardo Samuel    male  18.0      0
# ...      ...                                   ...     ...   ...    ...
# 1265       3             Van Impe, Miss. Catharina  female  10.0      0
# 1273       3    Vander Planke, Miss. Augusta Maria  female  18.0      2
# 1275       3       Vander Planke, Mr. Leo Edmondus    male  16.0      2
# 1279       3  Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 1288       3             Wiklund, Mr. Jakob Alfred    male  18.0      1
#
#       parch   ticket      fare        cabin embarked  survived
# ...

# %%
df[(df['pclass']==3) & (df['survived']==1)]
# Out:
#       pclass                                             name     sex   age  \
# 603        3                 Abbott, Mrs. Stanton (Rosa Hunt)  female  35.0
# 604        3                      Abelseth, Miss. Karen Marie  female  16.0
# 605        3                    Abelseth, Mr. Olaus Jorgensen    male  25.0
# 606        3         Abrahamsson, Mr. Abraham August Johannes    male  20.0
# 607        3        Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0
# ...      ...                                              ...     ...   ...
# 1261       3                           Turkula, Mrs. (Hedwig)  female  63.0
# 1277       3                             Vartanian, Mr. David    male  22.0
# 1286       3  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)  female  38.0
# 1290       3                 Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 1300       3          Yasbeck, Mrs. Antoni (Selini Alexander)  female  15.0
#
# ...

# %%
df[(df['sibsp']>=1)]
# Out:
#       pclass                                             name     sex  \
# 1          1                   Allison, Master. Hudson Trevor    male
# 2          1                     Allison, Miss. Helen Loraine  female
# 3          1             Allison, Mr. Hudson Joshua Creighton    male
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 6          1                Andrews, Miss. Kornelia Theodosia  female
# ...      ...                                              ...     ...
# 1290       3                 Wilkes, Mrs. James (Ellen Needs)  female
# 1299       3                              Yasbeck, Mr. Antoni    male
# 1300       3          Yasbeck, Mrs. Antoni (Selini Alexander)  female
# 1304       3                             Zabour, Miss. Hileni  female
# 1305       3                            Zabour, Miss. Thamine  female
#
#           age  sibsp  parch  ticket      fare    cabin embarked  survived
# ...

# %%
df[(df['sex']=='male') & (df['age']>60) & (df['embarked']=='Q') &(df['survived']==1)]
# Out:
# Empty DataFrame
# Columns: [pclass, name, sex, age, sibsp, parch, ticket, fare, cabin, embarked, survived]
# Index: []

# %%
df1=pd.read_csv('https://raw.githubusercontent.com/rajeevratan84/datascienceforbusiness/master/hr_data.csv')

# %%
df1
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 0             1003               2                   157                   3
# 1             1005               5                   262                   6
# 2             1486               7                   272                   4
# 3             1038               5                   223                   5
# 4             1057               2                   159                   3
# ...            ...             ...                   ...                 ...
# 14994        87670               2                   151                   3
# 14995        87673               2                   160                   3
# 14996        87679               2                   143                   3
# 14997        87681               6                   280                   4
# 14998        87684               2                   158                   3
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   employee_id            14999 non-null  int64
#  1   number_project         14999 non-null  int64
#  2   average_montly_hours   14999 non-null  int64
#  3   time_spend_company     14999 non-null  int64
#  4   Work_accident          14999 non-null  int64
#  5   left                   14999 non-null  int64
#  6   promotion_last_5years  14999 non-null  int64
#  7   department             14999 non-null  object
#  8   salary                 14999 non-null  object
# dtypes: int64(7), object(2)
# memory usage: 1.0+ MB

# %%
df1[(df1['department']=='sales') | (df1['department']=='accounting')]
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 0             1003               2                   157                   3
# 1             1005               5                   262                   6
# 2             1486               7                   272                   4
# 3             1038               5                   223                   5
# 4             1057               2                   159                   3
# ...            ...             ...                   ...                 ...
# 14970        87530               4                   225                   5
# 14971        87533               2                   140                   3
# 14972        87539               6                   310                   4
# 14973         7745               2                   143                   3
# 14974        87545               2                   153                   3
#
# ...

# %%
df1[(df1['department']=='IT') & (df1['left']==1) ]
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 61            1399               7                   308                   4
# 62            1404               6                   244                   5
# 63            1413               2                   132                   3
# 64           42423               6                   286                   4
# 65            1424               6                   161                   4
# ...            ...             ...                   ...                 ...
# 14930        87284               6                   268                   4
# 14931        87288               5                   240                   5
# 14932        87294               2                   127                   3
# 14933        87308               7                   264                   4
# 14938        45511               4                   271                   5
#
# ...

# %%
df1[(df1['number_project']>5)]
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 2             1486               7                   272                   4
# 6             1061               6                   247                   4
# 11            1088               6                   305                   4
# 20            1148               6                   282                   4
# 22            1158               6                   304                   4
# ...            ...             ...                   ...                 ...
# 14975        87560               7                   310                   4
# 14979        87581               6                   296                   4
# 14991        87654               6                   257                   4
# 14993        87661               6                   293                   6
# 14997        87681               6                   280                   4
#
# ...

# %%
df1[(df1['promotion_last_5years']==1) & (df1['department']=='accounting')]
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 4506         26744               5                   135                   2
# 4734         27917               4                   167                   3
# 5038          9960               5                   192                   3
# 5524         32520               5                   171                   6
# 5525         73111               4                   232                   3
# 5526         73511               5                   172                   2
# 11213        65762               5                   176                   6
# 11214        65764               5                   264                   8
# 11215        65770               3                   261                   8
# 11400        66768               3                   150                   4
# 13424        78430               5                   176                   6
# ...

# %%
df1[(df1['salary']=='low') | (df1['salary']=='medium')]
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 0             1003               2                   157                   3
# 1             1005               5                   262                   6
# 2             1486               7                   272                   4
# 3             1038               5                   223                   5
# 4             1057               2                   159                   3
# ...            ...             ...                   ...                 ...
# 14994        87670               2                   151                   3
# 14995        87673               2                   160                   3
# 14996        87679               2                   143                   3
# 14997        87681               6                   280                   4
# 14998        87684               2                   158                   3
#
# ...

# %%
df[df['fare'].isnull()]
# Out:
#       pclass                name   sex   age  sibsp  parch ticket  fare cabin  \
# 1225       3  Storey, Mr. Thomas  male  60.5      0      0   3701   NaN   NaN
#
#      embarked  survived
# 1225        S         0

# %%
df.info()
df[df['sex'].notnull()]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    1309 non-null   int64
#  1   name      1309 non-null   object
#  2   sex       1309 non-null   object
#  3   age       1046 non-null   float64
#  4   sibsp     1309 non-null   int64
#  5   parch     1309 non-null   int64
#  6   ticket    1309 non-null   object
#  7   fare      1308 non-null   float64
#  8   cabin     295 non-null    object
#  9   embarked  1307 non-null   object
#  10  survived  1309 non-null   int64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 112.6+ KB
#       pclass                                             name     sex  \
# 0          1                    Allen, Miss. Elisabeth Walton  female
# 1          1                   Allison, Master. Hudson Trevor    male
# 2          1                     Allison, Miss. Helen Loraine  female
# ...

# %%
df[df['cabin'].isnull()]
# Out:
#       pclass                          name     sex   age  sibsp  parch  \
# 9          1       Artagaveytia, Mr. Ramon    male  71.0      0      0
# 13         1  Barber, Miss. Ellen "Nellie"  female  26.0      0      0
# 15         1           Baumann, Mr. John D    male   NaN      0      0
# 23         1         Bidois, Miss. Rosalie  female  42.0      0      0
# 25         1           Birnbaum, Mr. Jakob    male  25.0      0      0
# ...      ...                           ...     ...   ...    ...    ...
# 1304       3          Zabour, Miss. Hileni  female  14.5      1      0
# 1305       3         Zabour, Miss. Thamine  female   NaN      1      0
# 1306       3     Zakarian, Mr. Mapriededer    male  26.5      0      0
# 1307       3           Zakarian, Mr. Ortin    male  27.0      0      0
# 1308       3            Zimmerman, Mr. Leo    male  29.0      0      0
#
#         ticket      fare cabin embarked  survived
# 9     PC 17609   49.5042   NaN        C         0
# ...

# %%
df[df['age'].notnull()]
# Out:
#       pclass                                             name     sex  \
# 0          1                    Allen, Miss. Elisabeth Walton  female
# 1          1                   Allison, Master. Hudson Trevor    male
# 2          1                     Allison, Miss. Helen Loraine  female
# 3          1             Allison, Mr. Hudson Joshua Creighton    male
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...      ...                                              ...     ...
# 1301       3                             Youseff, Mr. Gerious    male
# 1304       3                             Zabour, Miss. Hileni  female
# 1306       3                        Zakarian, Mr. Mapriededer    male
# 1307       3                              Zakarian, Mr. Ortin    male
# 1308       3                               Zimmerman, Mr. Leo    male
#
#           age  sibsp  parch  ticket      fare    cabin embarked  survived
# ...
